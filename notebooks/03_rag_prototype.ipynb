# %% [markdown]
# # 03 — RAG prototype
#
# **Purpose:** prototype the Career Mentor chain end to end and tune the prompt
# before it becomes `src/mentor/rag_chain.py`.
#
# - Index `data/career_notes/`
# - Wire retriever -> prompt -> LLM with LangChain
# - Inspect retrieved chunks alongside each answer
# - Iterate on the prompt and record what changed
#
# _Status: placeholder — the RAG pipeline is deliberately NOT written yet (Step 6)._
