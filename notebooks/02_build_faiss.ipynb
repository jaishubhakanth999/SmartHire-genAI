# %% [markdown]
# # 02 — Build the FAISS index
#
# **Purpose:** build and verify the job index interactively before the logic is
# promoted into `src/search/embed.py`.
#
# - Load and chunk everything in `data/jobs/`
# - Embed the chunks and build the FAISS index
# - Persist it to `vectorstore/`
# - Reload it and confirm a test query returns sensible jobs
#
# _Status: placeholder — the index is deliberately NOT built yet (Step 3)._
